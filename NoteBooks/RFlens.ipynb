# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name.lower() in ["notebooks", "notebook"]:
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))

from Utility.RF import run_rf_inference

input_csv = PROJECT_ROOT / "data" / "cleaned_lightcurves.csv"
model_path = PROJECT_ROOT / "models" / "lens22_rf.joblib"
output_csv = PROJECT_ROOT / "data" / "rf_pair_predictions.csv"

pred_pairs = run_rf_inference(
    input_csv=input_csv,
    model_path=model_path,
    output_csv=output_csv,
    batch_size=64,
    keep_failed_pairs=True,
    verbose=True,
)

pred_pairs.head()
# Out:
# Processed 50 pairs | scored=50 | failed=0
# Processed 100 pairs | scored=100 | failed=0
# Processed 150 pairs | scored=150 | failed=0
# Processed 200 pairs | scored=200 | failed=0
# Processed 250 pairs | scored=250 | failed=0
# Processed 300 pairs | scored=300 | failed=0
# Processed 350 pairs | scored=350 | failed=0
# Processed 400 pairs | scored=400 | failed=0
# Processed 450 pairs | scored=450 | failed=0
# Processed 500 pairs | scored=500 | failed=0
# Processed 550 pairs | scored=550 | failed=0
# Processed 600 pairs | scored=600 | failed=0
# Processed 650 pairs | scored=650 | failed=0
# Processed 700 pairs | scored=700 | failed=0
# Processed 750 pairs | scored=750 | failed=0
# Processed 800 pairs | scored=800 | failed=0
# Processed 850 pairs | scored=850 | failed=0
# Processed 900 pairs | scored=900 | failed=0
# Processed 950 pairs | scored=950 | failed=0
# Processed 1000 pairs | scored=1000 | failed=0
# Processed 1050 pairs | scored=1050 | failed=0
# ...
